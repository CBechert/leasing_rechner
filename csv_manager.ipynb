# %%
import pandas as pd

# %%
leasing_list = [
    {"Laufzeit": 6, "Freikilometer": 15000, "Leasingrate": 0.9, "Tankguthaben": 0, "Bedingung": "Verbrenner"},
    {"Laufzeit": 12, "Freikilometer": 30000, "Leasingrate": 1.0, "Tankguthaben": 0, "Bedingung": "Verbrenner"},
    {"Laufzeit": 6, "Freikilometer": 15000, "Leasingrate": 0.8, "Tankguthaben": 0, "Bedingung": "Elektro/Hybrid"},
    {"Laufzeit": 12, "Freikilometer": 30000, "Leasingrate": 0.9, "Tankguthaben": 0, "Bedingung": "Elektro/Hybrid"},
    {"Laufzeit": 6, "Freikilometer": 15000, "Leasingrate": 1.0, "Tankguthaben": 90, "Bedingung": "Caddy"},
    {"Laufzeit": 12, "Freikilometer": 30000, "Leasingrate": 1.0, "Tankguthaben": 180, "Bedingung": "Caddy"},
    {"Laufzeit": 6, "Freikilometer": 15000, "Leasingrate": 1.0, "Tankguthaben": 160, "Bedingung": "Multivan"},
    {"Laufzeit": 12, "Freikilometer": 30000, "Leasingrate": 1.0, "Tankguthaben": 320, "Bedingung": "Multivan"},
]

# %%
polo = [
    {"Modell": "Polo", "Ausstattungslinie": "R-Line",   "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Polo", "Ausstattungslinie": "GTI",      "Motor": "2.0 TSI", "Leistung": 152, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Polo", "Ausstattungslinie": "Energy",   "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
]

# %%
t_cross = [
    {"Modell": "T-Cross", "Ausstattungslinie": "Life",      "Motor": "1.0 TSI", "Leistung": 70, "Getriebe": "5-Gang"},
    {"Modell": "T-Cross", "Ausstattungslinie": "Life",      "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "T-Cross", "Ausstattungslinie": "Life",      "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    {"Modell": "T-Cross", "Ausstattungslinie": "Life",      "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "T-Cross", "Ausstattungslinie": "Style",     "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "T-Cross", "Ausstattungslinie": "Style",     "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    {"Modell": "T-Cross", "Ausstattungslinie": "Style",     "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "T-Cross", "Ausstattungslinie": "R-Line",    "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "T-Cross", "Ausstattungslinie": "R-Line",    "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    {"Modell": "T-Cross", "Ausstattungslinie": "R-Line",    "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "T-Cross", "Ausstattungslinie": "Energy",    "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "T-Cross", "Ausstattungslinie": "Energy",    "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    {"Modell": "T-Cross", "Ausstattungslinie": "Energy",    "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
]

# %%
taigo = [
    {"Modell": "Taigo", "Ausstattungslinie": "Life",    "Motor": "1.0 TSI", "Leistung": 70, "Getriebe": "5-Gang"},
    {"Modell": "Taigo", "Ausstattungslinie": "Life",    "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Taigo", "Ausstattungslinie": "Life",    "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Taigo", "Ausstattungslinie": "Style",   "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Taigo", "Ausstattungslinie": "Style",   "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Taigo", "Ausstattungslinie": "Style",   "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Taigo", "Ausstattungslinie": "R-Line",  "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Taigo", "Ausstattungslinie": "R-Line",  "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Taigo", "Ausstattungslinie": "R-Line",  "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Taigo", "Ausstattungslinie": "Energy",  "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Taigo", "Ausstattungslinie": "Energy",  "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Taigo", "Ausstattungslinie": "Energy",  "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
]

# %%
t_roc = [
    {"Modell": "T-Roc", "Ausstattungslinie": "Life",    "Motor": "1.5 eTSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    {"Modell": "T-Roc", "Ausstattungslinie": "Life",    "Motor": "1.5 eTSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "T-Roc", "Ausstattungslinie": "Style",   "Motor": "1.5 eTSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    {"Modell": "T-Roc", "Ausstattungslinie": "Style",   "Motor": "1.5 eTSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "T-Roc", "Ausstattungslinie": "R-Line",  "Motor": "1.5 eTSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    ]

# %%
t_roc_cabriolet = [
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "Style",     "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "Style",     "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "6-Gang"},
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "Style",     "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "R-Line",    "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "6-Gang"},
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "R-Line",    "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "Energy",    "Motor": "1.0 TSI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "Energy",    "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "6-Gang"},
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "Energy",    "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
]

# %%
golf = [
    {"Modell": "Golf", "Ausstattungslinie": "Life",             "Motor": "1.5 TSI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Golf", "Ausstattungslinie": "Life",             "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "6-Gang"},
    {"Modell": "Golf", "Ausstattungslinie": "Life",             "Motor": "2.0 TDI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Golf", "Ausstattungslinie": "Life",             "Motor": "2.0 TDI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf", "Ausstattungslinie": "Life",             "Motor": "1.5 eTSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf", "Ausstattungslinie": "Life",             "Motor": "1.5 eTSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Golf", "Ausstattungslinie": "Style",            "Motor": "1.5 TSI",             "Leistung": 110, "Getriebe": "6-Gang"},
    {"Modell": "Golf", "Ausstattungslinie": "Style",            "Motor": "2.0 TSI | 4MOTION",   "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf", "Ausstattungslinie": "Style",            "Motor": "2.0 TDI",             "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf", "Ausstattungslinie": "Style",            "Motor": "1.5 eTSI",            "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Golf", "Ausstattungslinie": "R-Line",           "Motor": "1.5 TSI",             "Leistung": 110, "Getriebe": "6-Gang"},
    {"Modell": "Golf", "Ausstattungslinie": "R-Line",           "Motor": "2.0 TSI | 4MOTION",   "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf", "Ausstattungslinie": "R-Line",           "Motor": "2.0 TDI",             "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf", "Ausstattungslinie": "R-Line",           "Motor": "1.5 eTSI",            "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Golf", "Ausstattungslinie": "GTE",              "Motor": "1.5 eHybrid", "Leistung": 130, "Getriebe": "6-Gang-DSG"},
    
    {"Modell": "Golf", "Ausstattungslinie": "GTI",              "Motor": "2.0 TSI", "Leistung": 195, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Golf", "Ausstattungslinie": "GTI Clubsport",    "Motor": "2.0 TSI", "Leistung": 221, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Golf", "Ausstattungslinie": "R",                "Motor": "2.0 TSI | 4MOTION", "Leistung": 245, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Golf", "Ausstattungslinie": "Energy",           "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "6-Gang"},
    {"Modell": "Golf", "Ausstattungslinie": "Energy",           "Motor": "2.0 TDI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Golf", "Ausstattungslinie": "Energy",           "Motor": "2.0 TDI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf", "Ausstattungslinie": "Energy",           "Motor": "1.5 eTSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf", "Ausstattungslinie": "Energy",           "Motor": "1.5 eTSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf", "Ausstattungslinie": "Energy",           "Motor": "1.5 eHybrid", "Leistung": 110, "Getriebe": "6-Gang-DSG"},
]

# %%
golf_variant = [
    {"Modell": "Golf Variant", "Ausstattungslinie": "Style",    "Motor": "1.5 TSI",             "Leistung": 110, "Getriebe": "6-Gang"},
    {"Modell": "Golf Variant", "Ausstattungslinie": "Style",    "Motor": "2.0 TSI | 4MOTION",   "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf Variant", "Ausstattungslinie": "Style",    "Motor": "2.0 TDI",             "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf Variant", "Ausstattungslinie": "Style",    "Motor": "1.5 eTSI",            "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Golf Variant", "Ausstattungslinie": "R-Line",   "Motor": "1.5 TSI",             "Leistung": 110, "Getriebe": "6-Gang"},
    {"Modell": "Golf Variant", "Ausstattungslinie": "R-Line",   "Motor": "2.0 TSI | 4MOTION",   "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf Variant", "Ausstattungslinie": "R-Line",   "Motor": "2.0 TDI",             "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf Variant", "Ausstattungslinie": "R-Line",   "Motor": "1.5 eTSI",            "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Golf Variant", "Ausstattungslinie": "R",        "Motor": "2.0 TSI | 4MOTION", "Leistung": 245, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Golf Variant", "Ausstattungslinie": "Energy",   "Motor": "1.5 TSI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Golf Variant", "Ausstattungslinie": "Energy",   "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "6-Gang"},
    {"Modell": "Golf Variant", "Ausstattungslinie": "Energy",   "Motor": "2.0 TDI", "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Golf Variant", "Ausstattungslinie": "Energy",   "Motor": "2.0 TDI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf Variant", "Ausstattungslinie": "Energy",   "Motor": "1.5 eTSI", "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Golf Variant", "Ausstattungslinie": "Energy",   "Motor": "1.5 eTSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
]

# %%
passat = [
   {"Modell": "Passat", "Ausstattungslinie": "Business", "Motor": "2.0 TDI",     "Leistung": 90, "Getriebe": "7-Gang-DSG"},
   {"Modell": "Passat", "Ausstattungslinie": "Business", "Motor": "2.0 TDI",     "Leistung": 110, "Getriebe": "7-Gang-DSG"},
   {"Modell": "Passat", "Ausstattungslinie": "Business", "Motor": "1.5 eTSI",    "Leistung": 110, "Getriebe": "7-Gang-DSG"},
   {"Modell": "Passat", "Ausstattungslinie": "Business", "Motor": "1.5 eHybrid", "Leistung": 110, "Getriebe": "6-Gang-DSG"},
   {"Modell": "Passat", "Ausstattungslinie": "Business", "Motor": "1.5 eHybrid", "Leistung": 130, "Getriebe": "6-Gang-DSG"},
   
   {"Modell": "Passat", "Ausstattungslinie": "Elegance", "Motor": "2.0 TDI",           "Leistung": 110, "Getriebe": "7-Gang-DSG"},
   {"Modell": "Passat", "Ausstattungslinie": "Elegance", "Motor": "2.0 TDI | 4MOTION", "Leistung": 142, "Getriebe": "7-Gang-DSG"},
   {"Modell": "Passat", "Ausstattungslinie": "Elegance", "Motor": "1.5 eHybrid",       "Leistung": 110, "Getriebe": "6-Gang-DSG"},
   {"Modell": "Passat", "Ausstattungslinie": "Elegance", "Motor": "1.5 eHybrid",       "Leistung": 130, "Getriebe": "6-Gang-DSG"},
   
   {"Modell": "Passat", "Ausstattungslinie": "R-Line",   "Motor": "2.0 TSI | 4MOTION", "Leistung": 195, "Getriebe": "7-Gang-DSG"},
   {"Modell": "Passat", "Ausstattungslinie": "R-Line",   "Motor": "2.0 TDI",           "Leistung": 110, "Getriebe": "7-Gang-DSG"},
   {"Modell": "Passat", "Ausstattungslinie": "R-Line",   "Motor": "2.0 TDI | 4MOTION", "Leistung": 142, "Getriebe": "7-Gang-DSG"},
   {"Modell": "Passat", "Ausstattungslinie": "R-Line",   "Motor": "1.5 eHybrid",       "Leistung": 130, "Getriebe": "6-Gang-DSG"},
]

# %%
tiguan = [
    {"Modell": "Tiguan", "Ausstattungslinie": "Life",       "Motor": "2.0 TSI | 4MOTION",   "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "Life",       "Motor": "2.0 TDI",             "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "Life",       "Motor": "2.0 TDI | 4MOTION",   "Leistung": 142, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "Life",       "Motor": "1.5 eTSI",            "Leistung": 96, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "Life",       "Motor": "1.5 eTSI",            "Leistung": 110, "Getriebe": "7-Gang-DSG"},

    {"Modell": "Tiguan", "Ausstattungslinie": "Elegance",   "Motor": "2.0 TSI | 4MOTION",   "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "Elegance",   "Motor": "2.0 TDI",             "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "Elegance",   "Motor": "2.0 TDI | 4MOTION",   "Leistung": 142, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "Elegance",   "Motor": "1.5 eTSI",            "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "Elegance",   "Motor": "1.5 eHybrid",         "Leistung": 110, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "Elegance",   "Motor": "1.5 eHybrid",         "Leistung": 130, "Getriebe": "6-Gang-DSG"},

    {"Modell": "Tiguan", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TSI | 4MOTION",   "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TSI | 4MOTION",   "Leistung": 195, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TDI",             "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TDI | 4MOTION",   "Leistung": 142, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "R-Line",     "Motor": "1.5 eTSI",            "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "R-Line",     "Motor": "1.5 eHybrid",         "Leistung": 110, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "R-Line",     "Motor": "1.5 eHybrid",         "Leistung": 130, "Getriebe": "6-Gang-DSG"},

    {"Modell": "Tiguan", "Ausstattungslinie": "Energy",     "Motor": "2.0 TSI | 4MOTION",   "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "Energy",     "Motor": "2.0 TDI",             "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "Energy",     "Motor": "2.0 TDI | 4MOTION",   "Leistung": 142, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "Energy",     "Motor": "1.5 eTSI",            "Leistung": 96, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "Energy",     "Motor": "1.5 eTSI",            "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tiguan", "Ausstattungslinie": "Energy",     "Motor": "1.5 eHybrid",         "Leistung": 110, "Getriebe": "6-Gang-DSG"},
]

# %%
tayron = [
    {"Modell": "Tayron", "Ausstattungslinie": "Life",       "Motor": "2.0 TSI | 4MOTION",   "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tayron", "Ausstattungslinie": "Life",       "Motor": "2.0 TDI",             "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tayron", "Ausstattungslinie": "Life",       "Motor": "2.0 TDI | 4MOTION",   "Leistung": 142, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tayron", "Ausstattungslinie": "Life",       "Motor": "1.5 eTSI",            "Leistung": 110, "Getriebe": "7-Gang-DSG"},

    {"Modell": "Tayron", "Ausstattungslinie": "Elegance",   "Motor": "2.0 TSI | 4MOTION",   "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tayron", "Ausstattungslinie": "Elegance",   "Motor": "2.0 TDI",             "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tayron", "Ausstattungslinie": "Elegance",   "Motor": "2.0 TDI | 4MOTION",   "Leistung": 142, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tayron", "Ausstattungslinie": "Elegance",   "Motor": "1.5 eTSI",            "Leistung": 110, "Getriebe": "7-Gang-DSG"},

    {"Modell": "Tayron", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TSI | 4MOTION",   "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tayron", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TSI | 4MOTION",   "Leistung": 195, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tayron", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TDI",             "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Tayron", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TDI | 4MOTION",   "Leistung": 142, "Getriebe": "7-Gang-DSG"},
]

# %%
touareg = [
    {"Modell": "Touareg", "Ausstattungslinie": "Elegance",  "Motor": "3.0 V6 TDI | 4MOTION", "Leistung": 170, "Getriebe": "8-Gang-Automatik"},
    {"Modell": "Touareg", "Ausstattungslinie": "Elegance",  "Motor": "3.0 V6 TDI | 4MOTION", "Leistung": 210, "Getriebe": "8-Gang-Automatik"},
    
    {"Modell": "Touareg", "Ausstattungslinie": "R-Line",    "Motor": "3.0 V6 TDI | 4MOTION", "Leistung": 170, "Getriebe": "8-Gang-Automatik"},
    {"Modell": "Touareg", "Ausstattungslinie": "R-Line",    "Motor": "3.0 V6 TDI | 4MOTION", "Leistung": 210, "Getriebe": "8-Gang-Automatik"},
]

# %%
touran = [
   {"Modell": "Touran", "Ausstattungslinie": "Comfortline", "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "6-Gang"},
   {"Modell": "Touran", "Ausstattungslinie": "Comfortline", "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
   {"Modell": "Touran", "Ausstattungslinie": "Comfortline", "Motor": "2.0 TDI", "Leistung": 90, "Getriebe": "6-Gang"},
   {"Modell": "Touran", "Ausstattungslinie": "Comfortline", "Motor": "2.0 TDI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},

   {"Modell": "Touran", "Ausstattungslinie": "Highline",    "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "6-Gang"},
   {"Modell": "Touran", "Ausstattungslinie": "Highline",    "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
   {"Modell": "Touran", "Ausstattungslinie": "Highline",    "Motor": "2.0 TDI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},

   {"Modell": "Touran", "Ausstattungslinie": "Energy",      "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "6-Gang"},
   {"Modell": "Touran", "Ausstattungslinie": "Energy",      "Motor": "1.5 TSI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
   {"Modell": "Touran", "Ausstattungslinie": "Energy",      "Motor": "2.0 TDI", "Leistung": 90, "Getriebe": "6-Gang"},
   {"Modell": "Touran", "Ausstattungslinie": "Energy",      "Motor": "2.0 TDI", "Leistung": 110, "Getriebe": "7-Gang-DSG"},
]

# %%
id_4 = [
    {"Modell": "ID.4", "Ausstattungslinie": "Pro", "Motor": "77 kWh", "Leistung": 210, "Getriebe": "1-Gang-DSG"},
    {"Modell": "ID.4", "Ausstattungslinie": "Pro", "Motor": "77 kWh | 4MOTION", "Leistung": 210, "Getriebe": "1-Gang-DSG"},
    
    {"Modell": "ID.4", "Ausstattungslinie": "GTX", "Motor": "79 kWh | 4MOTION", "Leistung": 250, "Getriebe": "1-Gang-DSG"},
]

# %%
id_5 = [
    {"Modell": "ID.5", "Ausstattungslinie": "Pro", "Motor": "77 kWh", "Leistung": 210, "Getriebe": "1-Gang-DSG"},
    
    {"Modell": "ID.5", "Ausstattungslinie": "GTX", "Motor": "79 kWh | 4MOTION", "Leistung": 250, "Getriebe": "1-Gang-DSG"},
]

# %%
id_7 = [
    {"Modell": "ID.7", "Ausstattungslinie": "Pro S", "Motor": "86 kWh", "Leistung": 210, "Getriebe": "1-Gang-DSG"},
]

# %%
id_7_tourer = [
    {"Modell": "ID.7 Tourer", "Ausstattungslinie": "Pro S", "Motor": "86 kWh", "Leistung": 210, "Getriebe": "1-Gang-DSG"},
]

# %%
caddy = [
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy", "Motor": "2.0 TDI",           "Leistung": 75, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy", "Motor": "2.0 TDI",           "Leistung": 90, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy", "Motor": "2.0 TDI | 4MOTION", "Leistung": 90, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy", "Motor": "1.5 eHybrid",       "Leistung": 85, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy", "Motor": "1.5 TSI",           "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy", "Motor": "1.5 TSI",           "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy Maxi", "Motor": "2.0 TDI",              "Leistung": 75, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy Maxi", "Motor": "2.0 TDI ",             "Leistung": 90, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy Maxi", "Motor": "2.0 TDI | 4MOTION",    "Leistung": 90, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy Maxi", "Motor": "1.5 eHybrid",          "Leistung": 85, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy Maxi", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy Maxi", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Caddy", "Ausstattungslinie": "Life", "Motor": "2.0 TDI",              "Leistung": 75, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Life", "Motor": "2.0 TDI ",             "Leistung": 90, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Life", "Motor": "2.0 TDI | 4MOTION",    "Leistung": 90, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Life", "Motor": "1.5 eHybrid",          "Leistung": 85, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Life", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Life", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "7-Gang-DSG"},

    {"Modell": "Caddy", "Ausstattungslinie": "Life Maxi", "Motor": "2.0 TDI",              "Leistung": 75, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Life Maxi", "Motor": "2.0 TDI ",             "Leistung": 90, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Life Maxi", "Motor": "2.0 TDI | 4MOTION",    "Leistung": 90, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Life Maxi", "Motor": "1.5 eHybrid",          "Leistung": 85, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Life Maxi", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Life Maxi", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "7-Gang-DSG"},

    {"Modell": "Caddy", "Ausstattungslinie": "Style", "Motor": "2.0 TDI ",             "Leistung": 90, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Style", "Motor": "2.0 TDI | 4MOTION",    "Leistung": 90, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Style", "Motor": "1.5 eHybrid",          "Leistung": 85, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Style", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Style", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "7-Gang-DSG"},

    {"Modell": "Caddy", "Ausstattungslinie": "Style Maxi", "Motor": "2.0 TDI ",             "Leistung": 90, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Style Maxi", "Motor": "2.0 TDI | 4MOTION",    "Leistung": 90, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Style Maxi", "Motor": "1.5 eHybrid",          "Leistung": 85, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Style Maxi", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Style Maxi", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "7-Gang-DSG"},

    {"Modell": "Caddy", "Ausstattungslinie": "Energy", "Motor": "2.0 TDI",              "Leistung": 75, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Energy", "Motor": "2.0 TDI ",             "Leistung": 90, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Energy", "Motor": "2.0 TDI | 4MOTION",    "Leistung": 90, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Energy", "Motor": "1.5 eHybrid",          "Leistung": 85, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Energy", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Energy", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Caddy", "Ausstattungslinie": "Energy Maxi", "Motor": "2.0 TDI",              "Leistung": 75, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Energy Maxi", "Motor": "2.0 TDI ",             "Leistung": 90, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Energy Maxi", "Motor": "2.0 TDI | 4MOTION",    "Leistung": 90, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Energy Maxi", "Motor": "1.5 eHybrid",          "Leistung": 85, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "Energy Maxi", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "Energy Maxi", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Caddy", "Ausstattungslinie": "PanAmericana", "Motor": "2.0 TDI",              "Leistung": 75, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "PanAmericana", "Motor": "2.0 TDI ",             "Leistung": 90, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "PanAmericana", "Motor": "2.0 TDI | 4MOTION",    "Leistung": 90, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "PanAmericana", "Motor": "1.5 eHybrid",          "Leistung": 85, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Caddy", "Ausstattungslinie": "PanAmericana", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "6-Gang"},
    {"Modell": "Caddy", "Ausstattungslinie": "PanAmericana", "Motor": "1.5 TSI",              "Leistung": 85, "Getriebe": "7-Gang-DSG"},
]

# %%
multivan = [
    {"Modell": "Multivan", "Ausstattungslinie": "Multivan", "Motor": "2.0 TDI | KÜ",                        "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Multivan", "Motor": "1.5 eHybrid | 19.7 kWh | 4MOTION",    "Leistung": 130, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Multivan", "Motor": "2.0 TSI | KÜ",                        "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Multivan", "Motor": "2.0 TDI | LÜ",                        "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Multivan", "Motor": "1.5 eHybrid | 19.7 kWh | 4MOTION",    "Leistung": 130, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Multivan", "Motor": "2.0 TSI | LÜ",                        "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    
    {"Modell": "Multivan", "Ausstattungslinie": "Life", "Motor": "2.0 TDI | KÜ",                        "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Life", "Motor": "1.5 eHybrid | 19.7 kWh | 4MOTION",    "Leistung": 130, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Life", "Motor": "2.0 TSI | KÜ",                        "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Life", "Motor": "2.0 TDI | LÜ",                        "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Life", "Motor": "1.5 eHybrid | 19.7 kWh | 4MOTION",    "Leistung": 130, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Life", "Motor": "2.0 TSI | LÜ",                        "Leistung": 150, "Getriebe": "7-Gang-DSG"},

    {"Modell": "Multivan", "Ausstattungslinie": "Style", "Motor": "2.0 TDI | KÜ",                        "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Style", "Motor": "1.5 eHybrid | 19.7 kWh | 4MOTION",    "Leistung": 130, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Style", "Motor": "2.0 TSI | KÜ",                        "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Style", "Motor": "2.0 TDI | LÜ",                        "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Style", "Motor": "1.5 eHybrid | 19.7 kWh | 4MOTION",    "Leistung": 130, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Style", "Motor": "2.0 TSI | LÜ",                        "Leistung": 150, "Getriebe": "7-Gang-DSG"},

    {"Modell": "Multivan", "Ausstattungslinie": "Energy", "Motor": "2.0 TDI | KÜ",                        "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Energy", "Motor": "1.5 eHybrid | 19.7 kWh | 4MOTION",    "Leistung": 130, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Energy", "Motor": "2.0 TSI | KÜ",                        "Leistung": 150, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Energy", "Motor": "2.0 TDI | LÜ",                        "Leistung": 110, "Getriebe": "7-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Energy", "Motor": "1.5 eHybrid | 19.7 kWh | 4MOTION",    "Leistung": 130, "Getriebe": "6-Gang-DSG"},
    {"Modell": "Multivan", "Ausstattungslinie": "Energy", "Motor": "2.0 TSI | LÜ",                        "Leistung": 150, "Getriebe": "7-Gang-DSG"},
]

# %%
auto_list= [
    *polo,
    *t_cross,
    *taigo,
    *t_roc,
    *t_roc_cabriolet,
    *golf,
    *golf_variant,
    *touran,
    *tiguan,
    *tayron,
    *passat,
    *touareg,
    *id_4,
    *id_5,
    *id_7,
    *id_7_tourer,
    *caddy,
    *multivan
    ]

# %%
# Auto-CSV anlegen
autos = pd.DataFrame(auto_list)

# Leasing-CSV anlegen
leasing = pd.DataFrame(leasing_list)

# Speichern
autos.to_csv("autos.csv", sep=";", index=False)
leasing.to_csv("leasing.csv", sep=";", index=False)

# %%
# Laden & bearbeiten
autos = pd.read_csv("autos.csv", sep=";")
leasing = pd.read_csv("leasing.csv", sep=";")

# %%
autos
# Out:
#        Modell Ausstattungslinie                             Motor  Leistung  \
# 0        Polo            R-Line                           1.0 TSI        85
# 1        Polo               GTI                           2.0 TSI       152
# 2        Polo            Energy                           1.0 TSI        85
# 3     T-Cross              Life                           1.0 TSI        70
# 4     T-Cross              Life                           1.0 TSI        85
# ..        ...               ...                               ...       ...
# 222  Multivan            Energy  1.5 eHybrid | 19.7 kWh | 4MOTION       130
# 223  Multivan            Energy                      2.0 TSI | KÜ       150
# 224  Multivan            Energy                      2.0 TDI | LÜ       110
# 225  Multivan            Energy  1.5 eHybrid | 19.7 kWh | 4MOTION       130
# 226  Multivan            Energy                      2.0 TSI | LÜ       150
#
#        Getriebe
# 0    7-Gang-DSG
# 1    7-Gang-DSG
# ...

# %%
leasing
# Out:
#    Laufzeit  Freikilometer  Leasingrate  Tankguthaben       Bedingung
# 0         6          15000          0.9             0      Verbrenner
# 1        12          30000          1.0             0      Verbrenner
# 2         6          15000          0.8             0  Elektro/Hybrid
# 3        12          30000          0.9             0  Elektro/Hybrid
# 4         6          15000          1.0            90           Caddy
# 5        12          30000          1.0           180           Caddy
# 6         6          15000          1.0           160        Multivan
# 7        12          30000          1.0           320        Multivan
