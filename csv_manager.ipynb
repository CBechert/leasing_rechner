# %%
import pandas as pd

# %%
leasing_list = [
    {"Leasingoption":"0.9 % | 6 Monate  | 15000 km | 0€ (Prepaid)",     "Leasingrate": 0.9, "Laufzeit": 6,  "Freikilometer": 15000, "Tankguthaben": 0, "Bedingung": "Verbrenner",        },
    {"Leasingoption":"1.0 % | 12 Monate | 30000 km | 0€ (Prepaid)",     "Leasingrate": 1.0, "Laufzeit": 12, "Freikilometer": 30000, "Tankguthaben": 0, "Bedingung": "Verbrenner",        },
    {"Leasingoption":"0.8 % | 6 Monate  | 15000 km | 0€ (Prepaid)",     "Leasingrate": 0.8, "Laufzeit": 6,  "Freikilometer": 15000, "Tankguthaben": 0, "Bedingung": "Elektro/Hybrid",    },
    {"Leasingoption":"0.9 % | 12 Monate | 30000 km | 0€ (Prepaid)",     "Leasingrate": 0.9, "Laufzeit": 12, "Freikilometer": 30000, "Tankguthaben": 0, "Bedingung": "Elektro/Hybrid",    },
    {"Leasingoption":"1.0 % | 6 Monate  | 15000 km | 90€ (Prepaid)",    "Leasingrate": 1.0, "Laufzeit": 6,  "Freikilometer": 15000, "Tankguthaben": 90, "Bedingung": "Caddy",            },
    {"Leasingoption":"1.0 % | 12 Monate | 30000 km | 180€ (Prepaid)",   "Leasingrate": 1.0, "Laufzeit": 12, "Freikilometer": 30000, "Tankguthaben": 180, "Bedingung": "Caddy",           },
    {"Leasingoption":"1.0 % | 6 Monate  | 15000 km | 160€ (Prepaid)",   "Leasingrate": 1.0, "Laufzeit": 6,  "Freikilometer": 15000, "Tankguthaben": 160, "Bedingung": "Multivan",        },
    {"Leasingoption":"1.0 % | 12 Monate | 30000 km | 320€ (Prepaid)",   "Leasingrate": 1.0, "Laufzeit": 12, "Freikilometer": 30000, "Tankguthaben": 320, "Bedingung": "Multivan",        },
]

# %%
polo = [
    {"Modell": "Polo", "Ausstattungslinie": "R-Line",   "Motor": "1.0 TSI | 85 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.6,     "kWh/100km": 0.0     },
    
    {"Modell": "Polo", "Ausstattungslinie": "GTI",      "Motor": "2.0 TSI | 152 kW | 7-Gang-DSG",   "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.7,     "kWh/100km": 0.0     },
    
    {"Modell": "Polo", "Ausstattungslinie": "Energy",   "Motor": "1.0 TSI | 85 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.6,     "kWh/100km": 0.0     },
]

# %%
t_cross = [
    {"Modell": "T-Cross", "Ausstattungslinie": "Life",      "Motor": "1.0 TSI | 70 kW | 5-Gang",         "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "T-Cross", "Ausstattungslinie": "Life",      "Motor": "1.0 TSI | 85 kW | 6-Gang",         "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.6,     "kWh/100km": 0.0     },
    {"Modell": "T-Cross", "Ausstattungslinie": "Life",      "Motor": "1.0 TSI | 85 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
    {"Modell": "T-Cross", "Ausstattungslinie": "Life",      "Motor": "1.5 TSI | 110 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.0,     "kWh/100km": 0.0     },
    
    {"Modell": "T-Cross", "Ausstattungslinie": "Style",     "Motor": "1.0 TSI | 85 kW | 6-Gang",         "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
    {"Modell": "T-Cross", "Ausstattungslinie": "Style",     "Motor": "1.0 TSI | 85 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.9,     "kWh/100km": 0.0     },
    {"Modell": "T-Cross", "Ausstattungslinie": "Style",     "Motor": "1.5 TSI | 110 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.1,     "kWh/100km": 0.0     },
    
    {"Modell": "T-Cross", "Ausstattungslinie": "R-Line",    "Motor": "1.0 TSI | 85 kW | 6-Gang",         "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
    {"Modell": "T-Cross", "Ausstattungslinie": "R-Line",    "Motor": "1.0 TSI | 85 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.9,     "kWh/100km": 0.0     },
    {"Modell": "T-Cross", "Ausstattungslinie": "R-Line",    "Motor": "1.5 TSI | 110 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.1,     "kWh/100km": 0.0     },
    
    {"Modell": "T-Cross", "Ausstattungslinie": "Energy",    "Motor": "1.0 TSI | 85 kW | 6-Gang",         "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "T-Cross", "Ausstattungslinie": "Energy",    "Motor": "1.0 TSI | 85 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.8,     "kWh/100km": 0.0     },
    {"Modell": "T-Cross", "Ausstattungslinie": "Energy",    "Motor": "1.5 TSI | 110 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.9,     "kWh/100km": 0.0     },
]

# %%
taigo = [
    {"Modell": "Taigo", "Ausstattungslinie": "Life",    "Motor": "1.0 TSI | 70 kW | 5-Gang",        "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.4,     "kWh/100km": 0.0     },
    {"Modell": "Taigo", "Ausstattungslinie": "Life",    "Motor": "1.0 TSI | 85 kW | 6-Gang",        "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.4,     "kWh/100km": 0.0     },
    {"Modell": "Taigo", "Ausstattungslinie": "Life",    "Motor": "1.0 TSI | 85 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.6,     "kWh/100km": 0.0     },
    
    {"Modell": "Taigo", "Ausstattungslinie": "Style",   "Motor": "1.0 TSI | 85 kW | 6-Gang",        "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.6,     "kWh/100km": 0.0     },
    {"Modell": "Taigo", "Ausstattungslinie": "Style",   "Motor": "1.0 TSI | 85 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
    {"Modell": "Taigo", "Ausstattungslinie": "Style",   "Motor": "1.5 TSI | 110 kW | 7-Gang-DSG",   "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.9,     "kWh/100km": 0.0     },
    
    {"Modell": "Taigo", "Ausstattungslinie": "R-Line",  "Motor": "1.0 TSI | 85 kW | 6-Gang",        "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.6,     "kWh/100km": 0.0     },
    {"Modell": "Taigo", "Ausstattungslinie": "R-Line",  "Motor": "1.0 TSI | 85 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
    {"Modell": "Taigo", "Ausstattungslinie": "R-Line",  "Motor": "1.5 TSI | 110 kW | 7-Gang-DSG",   "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.9,     "kWh/100km": 0.0     },
    
    {"Modell": "Taigo", "Ausstattungslinie": "Energy",  "Motor": "1.0 TSI | 85 kW | 6-Gang",        "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.4,     "kWh/100km": 0.0     },
    {"Modell": "Taigo", "Ausstattungslinie": "Energy",  "Motor": "1.0 TSI | 85 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "Taigo", "Ausstattungslinie": "Energy",  "Motor": "1.5 TSI | 110 kW | 7-Gang-DSG",   "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
]

# %%
t_roc = [
    {"Modell": "T-Roc", "Ausstattungslinie": "Life",    "Motor": "1.5 eTSI | 85 kW | 7-Gang-DSG",   "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "T-Roc", "Ausstattungslinie": "Life",    "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",  "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    
    {"Modell": "T-Roc", "Ausstattungslinie": "Style",   "Motor": "1.5 eTSI | 85 kW | 7-Gang-DSG",   "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
    {"Modell": "T-Roc", "Ausstattungslinie": "Style",   "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",  "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
    
    {"Modell": "T-Roc", "Ausstattungslinie": "R-Line",  "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",  "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
    ]

# %%
t_roc_cabriolet = [
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "Style",     "Motor": "1.0 TSI | 85 kW | 6-Gang",        "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.0,     "kWh/100km": 0.0     },
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "Style",     "Motor": "1.5 TSI | 110 kW | 6-Gang",       "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.3,     "kWh/100km": 0.0     },
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "Style",     "Motor": "1.5 TSI | 110 kW | 7-Gang-DSG",   "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.2,     "kWh/100km": 0.0     },
    
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "R-Line",    "Motor": "1.5 TSI | 110 kW | 6-Gang",       "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.2,     "kWh/100km": 0.0     },
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "R-Line",    "Motor": "1.5 TSI | 110 kW | 7-Gang-DSG",   "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.2,     "kWh/100km": 0.0     },
    
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "Energy",    "Motor": "1.0 TSI | 85 kW | 6-Gang",        "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.0,     "kWh/100km": 0.0     },
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "Energy",    "Motor": "1.5 TSI | 110 kW | 6-Gang",       "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.3,     "kWh/100km": 0.0     },
    {"Modell": "T-Roc Cabriolet", "Ausstattungslinie": "Energy",    "Motor": "1.5 TSI | 110 kW | 7-Gang-DSG",   "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.2,     "kWh/100km": 0.0     },
]

# %%
golf = [
    {"Modell": "Golf", "Ausstattungslinie": "Life",             "Motor": "1.5 TSI | 85 kW | 6-Gang",                    "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.4,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "Life",             "Motor": "1.5 TSI | 110 kW | 6-Gang",                   "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "Life",             "Motor": "2.0 TDI | 85 kW | 6-Gang",                    "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 4.3,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "Life",             "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 4.6,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "Life",             "Motor": "1.5 eTSI | 85 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.2,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "Life",             "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",              "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.3,     "kWh/100km": 0.0     },
    
    {"Modell": "Golf", "Ausstattungslinie": "Style",            "Motor": "1.5 TSI | 110 kW | 6-Gang",                   "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "Style",            "Motor": "2.0 TSI | 4MOTION | 150 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 7.0,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "Style",            "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 4.6,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "Style",            "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",              "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.2,     "kWh/100km": 0.0     },
    
    {"Modell": "Golf", "Ausstattungslinie": "R-Line",           "Motor": "1.5 TSI | 110 kW | 6-Gang",                   "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "R-Line",           "Motor": "2.0 TSI | 4MOTION | 150 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 7.0,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "R-Line",           "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 4.6,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "R-Line",           "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",              "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.3,     "kWh/100km": 0.0     },
    
    {"Modell": "Golf", "Ausstattungslinie": "GTE",              "Motor": "1.5 eHybrid | 130 kW | 6-Gang-DSG",           "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.3,     "kWh/100km": 15.9    },
    
    {"Modell": "Golf", "Ausstattungslinie": "GTI",              "Motor": "2.0 TSI | 195 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 7.1,     "kWh/100km": 0.0     },
    
    {"Modell": "Golf", "Ausstattungslinie": "GTI Clubsport",    "Motor": "2.0 TSI | 221 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 7.3,     "kWh/100km": 0.0     },
    
    {"Modell": "Golf", "Ausstattungslinie": "R",                "Motor": "2.0 TSI | 4MOTION | 245 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 8.2,     "kWh/100km": 0.0     },
    
    {"Modell": "Golf", "Ausstattungslinie": "Energy",           "Motor": "1.5 TSI | 110 kW | 6-Gang",                   "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "Energy",           "Motor": "2.0 TDI | 85 kW | 6-Gang",                    "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 4.3,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "Energy",           "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 4.5,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "Energy",           "Motor": "1.5 eTSI | 85 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.1,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "Energy",           "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",              "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.1,     "kWh/100km": 0.0     },
    {"Modell": "Golf", "Ausstattungslinie": "Energy",           "Motor": "1.5 eHybrid | 110 kW | 6-Gang-DSG",           "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.3,     "kWh/100km": 14.7    },
]

# %%
golf_variant = [
    {"Modell": "Golf Variant", "Ausstattungslinie": "Style",    "Motor": "1.5 TSI | 110 kW | 6-Gang",                   "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "Golf Variant", "Ausstattungslinie": "Style",    "Motor": "2.0 TSI | 4MOTION | 150 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 7.0,     "kWh/100km": 0.0     },
    {"Modell": "Golf Variant", "Ausstattungslinie": "Style",    "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 4.6,     "kWh/100km": 0.0     },
    {"Modell": "Golf Variant", "Ausstattungslinie": "Style",    "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",              "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.2,     "kWh/100km": 0.0     },
    
    {"Modell": "Golf Variant", "Ausstattungslinie": "R-Line",   "Motor": "1.5 TSI | 110 kW | 6-Gang",                   "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
    {"Modell": "Golf Variant", "Ausstattungslinie": "R-Line",   "Motor": "2.0 TSI | 4MOTION | 150 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 7.0,     "kWh/100km": 0.0     },
    {"Modell": "Golf Variant", "Ausstattungslinie": "R-Line",   "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 4.8,     "kWh/100km": 0.0     },
    {"Modell": "Golf Variant", "Ausstattungslinie": "R-Line",   "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",              "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.4,     "kWh/100km": 0.0     },
    
    {"Modell": "Golf Variant", "Ausstattungslinie": "R",        "Motor": "2.0 TSI | 4MOTION | 245 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 8.2,     "kWh/100km": 0.0     },
    
    {"Modell": "Golf Variant", "Ausstattungslinie": "Energy",   "Motor": "1.5 TSI | 85 kW | 6-Gang",                    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "Golf Variant", "Ausstattungslinie": "Energy",   "Motor": "1.5 TSI | 110 kW | 6-Gang",                   "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.4,     "kWh/100km": 0.0     },
    {"Modell": "Golf Variant", "Ausstattungslinie": "Energy",   "Motor": "2.0 TDI | 85 kW | 6-Gang",                    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 4.3,     "kWh/100km": 0.0     },
    {"Modell": "Golf Variant", "Ausstattungslinie": "Energy",   "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 4.7,     "kWh/100km": 0.0     },
    {"Modell": "Golf Variant", "Ausstattungslinie": "Energy",   "Motor": "1.5 eTSI | 85 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.0,     "kWh/100km": 0.0     },
    {"Modell": "Golf Variant", "Ausstattungslinie": "Energy",   "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",              "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.2,     "kWh/100km": 0.0     },
]

# %%
passat = [
   {"Modell": "Passat", "Ausstattungslinie": "Business", "Motor": "2.0 TDI | 90 kW | 7-Gang-DSG",              "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 4.9,     "kWh/100km": 0.0     },
   {"Modell": "Passat", "Ausstattungslinie": "Business", "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",             "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.0,     "kWh/100km": 0.0     },
   {"Modell": "Passat", "Ausstattungslinie": "Business", "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",            "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.4,     "kWh/100km": 0.0     },
   {"Modell": "Passat", "Ausstattungslinie": "Business", "Motor": "1.5 eHybrid | 110 kW | 6-Gang-DSG",         "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.3,     "kWh/100km": 16.2    },
   {"Modell": "Passat", "Ausstattungslinie": "Business", "Motor": "1.5 eHybrid | 130 kW | 6-Gang-DSG",         "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.3,     "kWh/100km": 16.3    },
   
   {"Modell": "Passat", "Ausstattungslinie": "Elegance", "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",             "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.0,     "kWh/100km": 0.0     },
   {"Modell": "Passat", "Ausstattungslinie": "Elegance", "Motor": "2.0 TDI | 4MOTION | 142 kW | 7-Gang-DSG",   "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
   {"Modell": "Passat", "Ausstattungslinie": "Elegance", "Motor": "1.5 eHybrid | 110 kW | 6-Gang-DSG",         "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.3,     "kWh/100km": 16.2    },
   {"Modell": "Passat", "Ausstattungslinie": "Elegance", "Motor": "1.5 eHybrid | 130 kW | 6-Gang-DSG",         "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.3,     "kWh/100km": 16.3    },
   
   {"Modell": "Passat", "Ausstattungslinie": "R-Line",   "Motor": "2.0 TSI | 4MOTION | 195 kW | 7-Gang-DSG",   "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 8.0,     "kWh/100km": 0.0     },
   {"Modell": "Passat", "Ausstattungslinie": "R-Line",   "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",             "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.2,     "kWh/100km": 0.0     },
   {"Modell": "Passat", "Ausstattungslinie": "R-Line",   "Motor": "2.0 TDI | 4MOTION | 142 kW | 7-Gang-DSG",   "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.9,     "kWh/100km": 0.0     },
   {"Modell": "Passat", "Ausstattungslinie": "R-Line",   "Motor": "1.5 eHybrid | 130 kW | 6-Gang-DSG",         "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.4,     "kWh/100km": 16.8    },
]

# %%
tiguan = [
    {"Modell": "Tiguan", "Ausstattungslinie": "Life",       "Motor": "2.0 TSI | 4MOTION | 150 kW | 7-Gang-DSG",      "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 7.6,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "Life",       "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",                "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.3,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "Life",       "Motor": "2.0 TDI | 4MOTION | 142 kW | 7-Gang-DSG",      "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 6.2,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "Life",       "Motor": "1.5 eTSI | 96 kW | 7-Gang-DSG",                "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 6.0,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "Life",       "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 6.0,     "kWh/100km": 0.0     },

    {"Modell": "Tiguan", "Ausstattungslinie": "Elegance",   "Motor": "2.0 TSI | 4MOTION | 150 kW | 7-Gang-DSG",      "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 7.6,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "Elegance",   "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",                "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.6,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "Elegance",   "Motor": "2.0 TDI | 4MOTION | 142 kW | 7-Gang-DSG",      "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 6.4,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "Elegance",   "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 6.1,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "Elegance",   "Motor": "1.5 eHybrid | 110 kW | 6-Gang-DSG",            "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.4,     "kWh/100km": 17.9    },
    {"Modell": "Tiguan", "Ausstattungslinie": "Elegance",   "Motor": "1.5 eHybrid | 130 kW | 6-Gang-DSG",            "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.4,     "kWh/100km": 17.9    },

    {"Modell": "Tiguan", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TSI | 4MOTION | 150 kW | 7-Gang-DSG",      "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 7.8,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TSI | 4MOTION | 195 kW | 7-Gang-DSG",      "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 8.4,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",                "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.6,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TDI | 4MOTION | 142 kW | 7-Gang-DSG",      "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 6.4,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "R-Line",     "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 6.1,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "R-Line",     "Motor": "1.5 eHybrid | 110 kW | 6-Gang-DSG",            "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.4,     "kWh/100km": 17.8    },
    {"Modell": "Tiguan", "Ausstattungslinie": "R-Line",     "Motor": "1.5 eHybrid | 130 kW | 6-Gang-DSG",            "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.4,     "kWh/100km": 17.6    },

    {"Modell": "Tiguan", "Ausstattungslinie": "Energy",     "Motor": "2.0 TSI | 4MOTION | 150 kW | 7-Gang-DSG",      "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 7.5,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "Energy",     "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",                "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "Energy",     "Motor": "2.0 TDI | 4MOTION | 142 kW | 7-Gang-DSG",      "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 6.2,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "Energy",     "Motor": "1.5 eTSI | 96 kW | 7-Gang-DSG",                "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 5.9,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "Energy",     "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 6.1,     "kWh/100km": 0.0     },
    {"Modell": "Tiguan", "Ausstattungslinie": "Energy",     "Motor": "1.5 eHybrid | 110 kW | 6-Gang-DSG",            "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.4,     "kWh/100km": 17.0    },
]

# %%
tayron = [
    {"Modell": "Tayron", "Ausstattungslinie": "Life",       "Motor": "2.0 TSI | 4MOTION | 150 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 7.6,     "kWh/100km": 0.0     },
    {"Modell": "Tayron", "Ausstattungslinie": "Life",       "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.4,     "kWh/100km": 0.0     },
    {"Modell": "Tayron", "Ausstattungslinie": "Life",       "Motor": "2.0 TDI | 4MOTION | 142 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.3,     "kWh/100km": 0.0     },
    {"Modell": "Tayron", "Ausstattungslinie": "Life",       "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",              "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.1,     "kWh/100km": 0.0     },

    {"Modell": "Tayron", "Ausstattungslinie": "Elegance",   "Motor": "2.0 TSI | 4MOTION | 150 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 7.7,     "kWh/100km": 0.0     },
    {"Modell": "Tayron", "Ausstattungslinie": "Elegance",   "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
    {"Modell": "Tayron", "Ausstattungslinie": "Elegance",   "Motor": "2.0 TDI | 4MOTION | 142 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.5,     "kWh/100km": 0.0     },
    {"Modell": "Tayron", "Ausstattungslinie": "Elegance",   "Motor": "1.5 eTSI | 110 kW | 7-Gang-DSG",              "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.1,     "kWh/100km": 0.0     },

    {"Modell": "Tayron", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TSI | 4MOTION | 150 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 7.8,     "kWh/100km": 0.0     },
    {"Modell": "Tayron", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TSI | 4MOTION | 195 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 8.5,     "kWh/100km": 0.0     },
    {"Modell": "Tayron", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",               "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
    {"Modell": "Tayron", "Ausstattungslinie": "R-Line",     "Motor": "2.0 TDI | 4MOTION | 142 kW | 7-Gang-DSG",     "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.5,     "kWh/100km": 0.0     },
]

# %%
touareg = [
    {"Modell": "Touareg", "Ausstattungslinie": "Elegance",  "Motor": "3.0 V6 TDI | 4MOTION | 170 kW | 8-Gang-Automatik",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 8.3,     "kWh/100km": 0.0     },
    {"Modell": "Touareg", "Ausstattungslinie": "Elegance",  "Motor": "3.0 V6 TDI | 4MOTION | 210 kW | 8-Gang-Automatik",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 8.2,     "kWh/100km": 0.0     },
    
    {"Modell": "Touareg", "Ausstattungslinie": "R-Line",    "Motor": "3.0 V6 TDI | 4MOTION | 170 kW | 8-Gang-Automatik",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 8.3,     "kWh/100km": 0.0     },
    {"Modell": "Touareg", "Ausstattungslinie": "R-Line",    "Motor": "3.0 V6 TDI | 4MOTION | 210 kW | 8-Gang-Automatik",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 8.3,     "kWh/100km": 0.0     },
]

# %%
touran = [
   {"Modell": "Touran", "Ausstattungslinie": "Comfortline", "Motor": "1.5 TSI | 110 kW | 6-Gang",        "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.6,     "kWh/100km": 0.0     },
   {"Modell": "Touran", "Ausstattungslinie": "Comfortline", "Motor": "1.5 TSI | 110 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.7,     "kWh/100km": 0.0     },
   {"Modell": "Touran", "Ausstattungslinie": "Comfortline", "Motor": "2.0 TDI | 90 kW | 6-Gang",         "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
   {"Modell": "Touran", "Ausstattungslinie": "Comfortline", "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },

   {"Modell": "Touran", "Ausstattungslinie": "Highline",    "Motor": "1.5 TSI | 110 kW | 6-Gang",        "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.7,     "kWh/100km": 0.0     },
   {"Modell": "Touran", "Ausstattungslinie": "Highline",    "Motor": "1.5 TSI | 110 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.7,     "kWh/100km": 0.0     },
   {"Modell": "Touran", "Ausstattungslinie": "Highline",    "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.6,     "kWh/100km": 0.0     },

   {"Modell": "Touran", "Ausstattungslinie": "Energy",      "Motor": "1.5 TSI | 110 kW | 6-Gang",        "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.6,     "kWh/100km": 0.0     },
   {"Modell": "Touran", "Ausstattungslinie": "Energy",      "Motor": "1.5 TSI | 110 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 6.7,     "kWh/100km": 0.0     },
   {"Modell": "Touran", "Ausstattungslinie": "Energy",      "Motor": "2.0 TDI | 90 kW | 6-Gang",         "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.4,     "kWh/100km": 0.0     },
   {"Modell": "Touran", "Ausstattungslinie": "Energy",      "Motor": "2.0 TDI | 110 kW | 7-Gang-DSG",    "Kategorie": "Verbrenner",     "Kraftstoff": "",     "l/100km": 5.4,     "kWh/100km": 0.0     },
]

# %%
id_4 = [
    {"Modell": "ID.4", "Ausstattungslinie": "Pro",      "Motor": "77 kWh | 210 kW | 1-Gang-DSG",                 "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.0,     "kWh/100km": 16.9     },
    {"Modell": "ID.4", "Ausstattungslinie": "Pro",      "Motor": "77 kWh | 4MOTION | 210 kW | 1-Gang-DSG",       "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.0,     "kWh/100km": 16.7     },
    
    {"Modell": "ID.4", "Ausstattungslinie": "GTX",      "Motor": "79 kWh | 4MOTION | 250 kW | 1-Gang-DSG",       "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.0,     "kWh/100km": 17.2     },
]

# %%
id_5 = [
    {"Modell": "ID.5", "Ausstattungslinie": "Pro",      "Motor": "77 kWh | 210 kW | 1-Gang-DSG",             "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.0,     "kWh/100km": 16.8     },
    
    {"Modell": "ID.5", "Ausstattungslinie": "GTX",      "Motor": "79 kWh | 4MOTION | 250 kW | 1-Gang-DSG",   "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.0,     "kWh/100km": 16.9     },
]

# %%
id_7 = [
    {"Modell": "ID.7", "Ausstattungslinie": "Pro S",    "Motor": "86 kWh | 210 kW | 1-Gang-DSG",   "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.0,     "kWh/100km": 14.0     },
]

# %%
id_7_tourer = [
    {"Modell": "ID.7 Tourer", "Ausstattungslinie": "Pro S",     "Motor": "86 kWh | 210 kW | 1-Gang-DSG",    "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.0,     "kWh/100km": 14.3     },
]

# %%
caddy = [
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy",           "Motor": "2.0 TDI | 75 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.3,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy",           "Motor": "2.0 TDI | 90 kW | 7-Gang-DSG",            "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy",           "Motor": "2.0 TDI | 4MOTION | 90 kW | 6-Gang",      "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.0,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy",           "Motor": "1.5 eHybrid | 85 kW | 6-Gang-DSG",        "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 0.5,     "kWh/100km": 18.6    },
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy",           "Motor": "1.5 TSI | 85 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.5,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy",           "Motor": "1.5 TSI | 85 kW | 7-Gang-DSG",            "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.6,     "kWh/100km": 0.0     },
    
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy Maxi",      "Motor": "2.0 TDI | 75 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy Maxi",      "Motor": "2.0 TDI  | 90 kW | 7-Gang-DSG",           "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.6,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy Maxi",      "Motor": "2.0 TDI | 4MOTION | 90 kW | 6-Gang",      "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.2,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy Maxi",      "Motor": "1.5 eHybrid | 85 kW | 6-Gang-DSG",        "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 0.5,     "kWh/100km": 19.0    },
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy Maxi",      "Motor": "1.5 TSI | 85 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.7,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Caddy Maxi",      "Motor": "1.5 TSI | 85 kW | 7-Gang-DSG",            "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.8,     "kWh/100km": 0.0     },
    
    {"Modell": "Caddy", "Ausstattungslinie": "Life",            "Motor": "2.0 TDI | 75 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.4,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Life",            "Motor": "2.0 TDI  | 90 kW | 7-Gang-DSG",           "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Life",            "Motor": "2.0 TDI | 4MOTION | 90 kW | 6-Gang",      "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.1,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Life",            "Motor": "1.5 eHybrid | 85 kW | 6-Gang-DSG",        "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 0.5,     "kWh/100km": 18.6    },
    {"Modell": "Caddy", "Ausstattungslinie": "Life",            "Motor": "1.5 TSI | 85 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.5,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Life",            "Motor": "1.5 TSI | 85 kW | 7-Gang-DSG",            "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.6,     "kWh/100km": 0.0     },

    {"Modell": "Caddy", "Ausstattungslinie": "Life Maxi",       "Motor": "2.0 TDI | 75 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.5,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Life Maxi",       "Motor": "2.0 TDI  | 90 kW | 7-Gang-DSG",           "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Life Maxi",       "Motor": "2.0 TDI | 4MOTION | 90 kW | 6-Gang",      "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.3,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Life Maxi",       "Motor": "1.5 eHybrid | 85 kW | 6-Gang-DSG",        "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 0.5,     "kWh/100km": 19.1    },
    {"Modell": "Caddy", "Ausstattungslinie": "Life Maxi",       "Motor": "1.5 TSI | 85 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.7,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Life Maxi",       "Motor": "1.5 TSI | 85 kW | 7-Gang-DSG",            "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.9,     "kWh/100km": 0.0     },

    {"Modell": "Caddy", "Ausstattungslinie": "Style",           "Motor": "2.0 TDI  | 90 kW | 7-Gang-DSG",           "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.6,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Style",           "Motor": "2.0 TDI | 4MOTION | 90 kW | 6-Gang",      "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.1,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Style",           "Motor": "1.5 eHybrid | 85 kW | 6-Gang-DSG",        "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 0.5,     "kWh/100km": 18.7    },
    {"Modell": "Caddy", "Ausstattungslinie": "Style",           "Motor": "1.5 TSI | 85 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.6,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Style",           "Motor": "1.5 TSI | 85 kW | 7-Gang-DSG",            "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.7,     "kWh/100km": 0.0     },

    {"Modell": "Caddy", "Ausstattungslinie": "Style Maxi",      "Motor": "2.0 TDI  | 90 kW | 7-Gang-DSG",           "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Style Maxi",      "Motor": "2.0 TDI | 4MOTION | 90 kW | 6-Gang",      "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.3,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Style Maxi",      "Motor": "1.5 eHybrid | 85 kW | 6-Gang-DSG",        "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 0.5,     "kWh/100km": 19.1    },
    {"Modell": "Caddy", "Ausstattungslinie": "Style Maxi",      "Motor": "1.5 TSI | 85 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.8,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Style Maxi",      "Motor": "1.5 TSI | 85 kW | 7-Gang-DSG",            "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.9,     "kWh/100km": 0.0     },

    {"Modell": "Caddy", "Ausstattungslinie": "Energy",          "Motor": "2.0 TDI | 75 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.4,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Energy",          "Motor": "2.0 TDI  | 90 kW | 7-Gang-DSG",           "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.6,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Energy",          "Motor": "2.0 TDI | 4MOTION | 90 kW | 6-Gang",      "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.1,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Energy",          "Motor": "1.5 eHybrid | 85 kW | 6-Gang-DSG",        "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 0.5,     "kWh/100km": 18.7    },
    {"Modell": "Caddy", "Ausstattungslinie": "Energy",          "Motor": "1.5 TSI | 85 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.6,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Energy",          "Motor": "1.5 TSI | 85 kW | 7-Gang-DSG",            "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.7,     "kWh/100km": 0.0     },
    
    {"Modell": "Caddy", "Ausstattungslinie": "Energy Maxi",     "Motor": "2.0 TDI | 75 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.6,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Energy Maxi",     "Motor": "2.0 TDI  | 90 kW | 7-Gang-DSG",           "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.7,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Energy Maxi",     "Motor": "2.0 TDI | 4MOTION | 90 kW | 6-Gang",      "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.3,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Energy Maxi",     "Motor": "1.5 eHybrid | 85 kW | 6-Gang-DSG",        "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 0.5,     "kWh/100km": 19.1    },
    {"Modell": "Caddy", "Ausstattungslinie": "Energy Maxi",     "Motor": "1.5 TSI | 85 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.8,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "Energy Maxi",     "Motor": "1.5 TSI | 85 kW | 7-Gang-DSG",            "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.9,     "kWh/100km": 0.0     },
    
    {"Modell": "Caddy", "Ausstattungslinie": "PanAmericana",    "Motor": "2.0 TDI | 75 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.4,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "PanAmericana",    "Motor": "2.0 TDI  | 90 kW | 7-Gang-DSG",           "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 5.6,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "PanAmericana",    "Motor": "2.0 TDI | 4MOTION | 90 kW | 6-Gang",      "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.1,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "PanAmericana",    "Motor": "1.5 eHybrid | 85 kW | 6-Gang-DSG",        "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 0.5,     "kWh/100km": 18.7    },
    {"Modell": "Caddy", "Ausstattungslinie": "PanAmericana",    "Motor": "1.5 TSI | 85 kW | 6-Gang",                "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.6,     "kWh/100km": 0.0     },
    {"Modell": "Caddy", "Ausstattungslinie": "PanAmericana",    "Motor": "1.5 TSI | 85 kW | 7-Gang-DSG",            "Kategorie": "Caddy",     "Kraftstoff": "",     "l/100km": 6.7,     "kWh/100km": 0.0     },
]

# %%
multivan = [
    {"Modell": "Multivan", "Ausstattungslinie": "Multivan",     "Motor": "KÜ | 2.0 TDI | 110 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 6.5,     "kWh/100km": 0.0     },
    {"Modell": "Multivan", "Ausstattungslinie": "Multivan",     "Motor": "KÜ | 1.5 eHybrid | 4MOTION | 130 kW | 6-Gang-DSG",    "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 0.9,     "kWh/100km": 22.5    },
    {"Modell": "Multivan", "Ausstattungslinie": "Multivan",     "Motor": "KÜ | 2.0 TSI | 150 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 8.9,     "kWh/100km": 0.0     },
    {"Modell": "Multivan", "Ausstattungslinie": "Multivan",     "Motor": "LÜ | 2.0 TDI | 110 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 6.5,     "kWh/100km": 0.0     },
    {"Modell": "Multivan", "Ausstattungslinie": "Multivan",     "Motor": "LÜ | 1.5 eHybrid | 4MOTION | 130 kW | 6-Gang-DSG",    "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 0.9,     "kWh/100km": 22.4    },
    {"Modell": "Multivan", "Ausstattungslinie": "Multivan",     "Motor": "LÜ | 2.0 TSI | 150 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 8.9,     "kWh/100km": 0.0     },
    
    {"Modell": "Multivan", "Ausstattungslinie": "Life",         "Motor": "KÜ | 2.0 TDI | 110 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 6.5,     "kWh/100km": 0.0     },
    {"Modell": "Multivan", "Ausstattungslinie": "Life",         "Motor": "KÜ | 1.5 eHybrid | 4MOTION | 130 kW | 6-Gang-DSG",    "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 0.9,     "kWh/100km": 22.5    },
    {"Modell": "Multivan", "Ausstattungslinie": "Life",         "Motor": "KÜ | 2.0 TSI | 150 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 8.9,     "kWh/100km": 0.0     },
    {"Modell": "Multivan", "Ausstattungslinie": "Life",         "Motor": "LÜ | 2.0 TDI | 110 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 6.6,     "kWh/100km": 0.0     },
    {"Modell": "Multivan", "Ausstattungslinie": "Life",         "Motor": "LÜ | 1.5 eHybrid | 4MOTION | 130 kW | 6-Gang-DSG",    "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 0.9,     "kWh/100km": 22.5    },
    {"Modell": "Multivan", "Ausstattungslinie": "Life",         "Motor": "LÜ | 2.0 TSI | 150 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 8.9,     "kWh/100km": 0.0     },

    {"Modell": "Multivan", "Ausstattungslinie": "Style",        "Motor": "KÜ | 2.0 TDI | 110 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 6.5,     "kWh/100km": 0.0     },
    {"Modell": "Multivan", "Ausstattungslinie": "Style",        "Motor": "KÜ | 1.5 eHybrid | 4MOTION | 130 kW | 6-Gang-DSG",    "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 0.9,     "kWh/100km": 22.4    },
    {"Modell": "Multivan", "Ausstattungslinie": "Style",        "Motor": "KÜ | 2.0 TSI | 150 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 8.8,     "kWh/100km": 0.0     },
    {"Modell": "Multivan", "Ausstattungslinie": "Style",        "Motor": "LÜ | 2.0 TDI | 110 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 6.5,     "kWh/100km": 0.0     },
    {"Modell": "Multivan", "Ausstattungslinie": "Style",        "Motor": "LÜ | 1.5 eHybrid | 4MOTION | 130 kW | 6-Gang-DSG",    "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 0.9,     "kWh/100km": 22.5    },
    {"Modell": "Multivan", "Ausstattungslinie": "Style",        "Motor": "LÜ | 2.0 TSI | 150 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 8.9,     "kWh/100km": 0.0     },

    {"Modell": "Multivan", "Ausstattungslinie": "Energy",       "Motor": "KÜ | 2.0 TDI | 110 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 6.6,     "kWh/100km": 0.0     },
    {"Modell": "Multivan", "Ausstattungslinie": "Energy",       "Motor": "KÜ | 1.5 eHybrid | 4MOTION | 130 kW | 6-Gang-DSG",    "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 0.9,     "kWh/100km": 22.5    },
    {"Modell": "Multivan", "Ausstattungslinie": "Energy",       "Motor": "KÜ | 2.0 TSI | 150 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 8.9,     "kWh/100km": 0.0     },
    {"Modell": "Multivan", "Ausstattungslinie": "Energy",       "Motor": "LÜ | 2.0 TDI | 110 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 6.6,     "kWh/100km": 0.0     },
    {"Modell": "Multivan", "Ausstattungslinie": "Energy",       "Motor": "LÜ | 1.5 eHybrid | 4MOTION | 130 kW | 6-Gang-DSG",    "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 0.9,     "kWh/100km": 22.5    },
    {"Modell": "Multivan", "Ausstattungslinie": "Energy",       "Motor": "LÜ | 2.0 TSI | 150 kW | 7-Gang-DSG",                  "Kategorie": "Multivan",     "Kraftstoff": "",     "l/100km": 8.9,     "kWh/100km": 0.0     },
]

# %%
california = [
    {"Modell": "California", "Ausstattungslinie": "Beach Camper Energy",    "Motor": "LÜ | 2.0 TDI | 110 kW | 7-Gang-DSG",                  "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 6.8,     "kWh/100km": 0.0     },
    {"Modell": "California", "Ausstattungslinie": "Beach Camper Energy",    "Motor": "LÜ | 1.5 eHybrid | 4MOTION | 130 kW | 6-Gang-DSG",    "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 0.9,     "kWh/100km": 23.1    },
    {"Modell": "California", "Ausstattungslinie": "Beach Camper Energy",    "Motor": "LÜ | 2.0 TSI | 150 kW | 7-Gang-DSG",                  "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 9.2,     "kWh/100km": 0.0     },
    
    {"Modell": "California", "Ausstattungslinie": "Coast Energy",           "Motor": "LÜ | 2.0 TDI | 110 kW | 7-Gang-DSG",                  "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 6.9,     "kWh/100km": 0.0     },
    {"Modell": "California", "Ausstattungslinie": "Coast Energy",           "Motor": "LÜ | 1.5 eHybrid | 4MOTION | 130 kW | 6-Gang-DSG",    "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 1.0,     "kWh/100km": 23.2    },
    {"Modell": "California", "Ausstattungslinie": "Coast Energy",           "Motor": "LÜ | 2.0 TSI | 150 kW | 7-Gang-DSG",                  "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 9.3,     "kWh/100km": 0.0     },

    {"Modell": "California", "Ausstattungslinie": "Ocean Energy",           "Motor": "LÜ | 2.0 TDI | 110 kW | 7-Gang-DSG",                  "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 6.9,     "kWh/100km": 0.0     },
    {"Modell": "California", "Ausstattungslinie": "Ocean Energy",           "Motor": "LÜ | 1.5 eHybrid | 4MOTION | 130 kW | 6-Gang-DSG",    "Kategorie": "Elektro/Hybrid",     "Kraftstoff": "",     "l/100km": 1.0,     "kWh/100km": 23.3    },
    {"Modell": "California", "Ausstattungslinie": "Ocean Energy",           "Motor": "LÜ | 2.0 TSI | 150 kW | 7-Gang-DSG",                  "Kategorie": "Verbrenner",         "Kraftstoff": "",     "l/100km": 9.3,     "kWh/100km": 0.0     },
]

# %%
auto_list= [
    *polo,
    *t_cross,
    *taigo,
    *t_roc,
    *t_roc_cabriolet,
    *golf,
    *golf_variant,
    *touran,
    *tiguan,
    *tayron,
    *passat,
    *touareg,
    *id_4,
    *id_5,
    *id_7,
    *id_7_tourer,
    *caddy,
    *multivan,
    *california
    ]

# %%
# Auto-CSV anlegen
autos = pd.DataFrame(auto_list)

# Leasing-CSV anlegen
leasing = pd.DataFrame(leasing_list)

# Speichern
autos.to_csv("autos.csv", sep=";", index=False)
leasing.to_csv("leasing.csv", sep=";", index=False)

# %%
# Laden & bearbeiten
autos = pd.read_csv("autos.csv", sep=";")
leasing = pd.read_csv("leasing.csv", sep=";")

# %%
autos
# Out:
#          Modell Ausstattungslinie  \
# 0          Polo            R-Line
# 1          Polo               GTI
# 2          Polo            Energy
# 3       T-Cross              Life
# 4       T-Cross              Life
# ..          ...               ...
# 231  California      Coast Energy
# 232  California      Coast Energy
# 233  California      Ocean Energy
# 234  California      Ocean Energy
# 235  California      Ocean Energy
#
#                                                 Motor       Kategorie  \
# 0                        1.0 TSI | 85 kW | 7-Gang-DSG      Verbrenner
# 1                       2.0 TSI | 152 kW | 7-Gang-DSG      Verbrenner
# 2                        1.0 TSI | 85 kW | 7-Gang-DSG      Verbrenner
# 3                            1.0 TSI | 70 kW | 5-Gang      Verbrenner
# 4                            1.0 TSI | 85 kW | 6-Gang      Verbrenner
# ..                                                ...             ...
# ...

# %%
leasing
# Out:
#                                    Leasingoption  Leasingrate  Laufzeit  \
# 0    0.9 % | 6 Monate  | 15000 km | 0€ (Prepaid)          0.9         6
# 1    1.0 % | 12 Monate | 30000 km | 0€ (Prepaid)          1.0        12
# 2    0.8 % | 6 Monate  | 15000 km | 0€ (Prepaid)          0.8         6
# 3    0.9 % | 12 Monate | 30000 km | 0€ (Prepaid)          0.9        12
# 4   1.0 % | 6 Monate  | 15000 km | 90€ (Prepaid)          1.0         6
# 5  1.0 % | 12 Monate | 30000 km | 180€ (Prepaid)          1.0        12
# 6  1.0 % | 6 Monate  | 15000 km | 160€ (Prepaid)          1.0         6
# 7  1.0 % | 12 Monate | 30000 km | 320€ (Prepaid)          1.0        12
#
#    Freikilometer  Tankguthaben       Bedingung
# 0          15000             0      Verbrenner
# 1          30000             0      Verbrenner
# 2          15000             0  Elektro/Hybrid
# 3          30000             0  Elektro/Hybrid
# 4          15000            90           Caddy
# ...

# %%
def kraftstoff_typ(motor):
    if "Hybrid" in motor:
        return "Hybrid"
    elif "kWh" in motor:
        return "Elektro"
    elif "TSI" in motor:
        return "Benzin"
    elif "TDI" in motor:
        return "Diesel"
    else:
        return ""

autos["Kraftstoff"] = autos["Motor"].apply(kraftstoff_typ)

# %%
autos
# Out:
#          Modell Ausstattungslinie  \
# 0          Polo            R-Line
# 1          Polo               GTI
# 2          Polo            Energy
# 3       T-Cross              Life
# 4       T-Cross              Life
# ..          ...               ...
# 231  California      Coast Energy
# 232  California      Coast Energy
# 233  California      Ocean Energy
# 234  California      Ocean Energy
# 235  California      Ocean Energy
#
#                                                 Motor       Kategorie  \
# 0                        1.0 TSI | 85 kW | 7-Gang-DSG      Verbrenner
# 1                       2.0 TSI | 152 kW | 7-Gang-DSG      Verbrenner
# 2                        1.0 TSI | 85 kW | 7-Gang-DSG      Verbrenner
# 3                            1.0 TSI | 70 kW | 5-Gang      Verbrenner
# 4                            1.0 TSI | 85 kW | 6-Gang      Verbrenner
# ..                                                ...             ...
# ...

# %%
# Speichern
autos.to_csv("autos.csv", sep=";", index=False)
leasing.to_csv("leasing.csv", sep=";", index=False)
